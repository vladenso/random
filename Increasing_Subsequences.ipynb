# %% [markdown]
# ### Given an integer array, your task is to find all the different possible increasing subsequences of the given array, and the length of an increasing subsequence should be at least 2 .

# %% [markdown]
# ### Example
# #### Input: [4, 6, 7, 7]
# Output: [[4, 6], [4, 7], [4, 6, 7], [4, 6, 7, 7], [6, 7], [6, 7, 7], [7,7], [4,7,7]]

# %%
def findSubsequences(nums):
    nums = sorted(nums)

# %%
nums = [4, 7, 6, 7]

# %%
 sorted(nums)
# Out:
# [4, 6, 7, 7]

# %%
nums
# Out:
# [4, 7, 6, 7]

# %%
import pandas as pd

# %%
data = pd.read_csv('../plum_lending/Lead_Verify_Response.csv')

# %%
data.describe()
# Out:
#              ORDER   Mailing Zip  Call Disposition
# count  10000.00000  10000.000000      10000.000000
# mean    5000.50000  50471.340100          3.331500
# std     2886.89568  29246.520818          2.022725
# min        1.00000   1001.000000          1.000000
# 25%     2500.75000  27408.500000          2.000000
# 50%     5000.50000  48174.000000          2.000000
# 75%     7500.25000  77006.000000          6.000000
# max    10000.00000  99901.000000          6.000000

# %%
data.loc[dates[1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-444d878ac2ca> in <module>()
# ----> 1 data.loc[dates[1]]
#
# NameError: name 'dates' is not defined

# %%
data
# Out:
#       ORDER   First Name   Last Name                 Mailing Street  \
# 0         1       Donald     Mathews            789 Cambridge Place
# 1         2       Sharon       Ogden         3929 Timber Ridge Road
# 2         3      Timothy       Villa              4493 Freedom Lane
# 3         4      Stephen     Jackson               1739 Five Points
# 4         5       Emilie      Sierra               2969 Bell Street
# 5         6       Roland   McQuiston          2786 Chardonnay Drive
# 6         7        Frank       Ayala           3151 Chestnut Street
# 7         8    Christina      Walker                4703 Buck Drive
# 8         9  Christopher       Burke             953 Heavner Avenue
# 9        10        Lance       Brown  2366 Emily Renzelli Boulevard
# 10       11       George        Mash           4512 Wildwood Street
# 11       12      Melissa      Valdes             1992 Ashwood Drive
# 12       13        Viola      Joiner            3315 Central Avenue
# 13       14       Glenda     Maxwell           3863 Southern Avenue
# 14       15         Thao       Brown               4074 Andell Road
# 15       16       Edmund      Burton               3688 Rose Street
# 16       17        David       Payne            1057 Wiseman Street
# 17       18         Nick        Wait             1983 Linden Avenue
# 18       19        Bambi      Garcia                446 Goff Avenue
# 19       20      Crystal      Barnes               465 Grand Avenue
# 20       21        Shawn      Hyland               1313 Yorkie Lane
# 21       22      Richard     Hornyak           839 Patterson Street
# 22       23       Willie     Ritzman          828 Abia Martin Drive
# 23       24        Debra       Moore      4973 University Hill Road
# 24       25        Jerry    Robinson                 8 Sunrise Road
# 25       26      Michael       Allen               4371 Bottom Lane
# 26       27      Deborah    Mitchell                   493 Poe Road
# 27       28      Michael    Thornton               702 Grand Avenue
# 28       29        David     Fontana            859 Woodside Circle
# 29       30       Angela      Burrus                1320 Maple Lane
# ...     ...          ...         ...                            ...
# 9970   9971        Irene       Roush           2750 Sunny Glen Lane
# 9971   9972        Roger     Montoya               544 Kimberly Way
# 9972   9973        Jorge       Fifer               2740 Andell Road
# 9971              Alto            MI        49302  909-949-8133
# 9972          Columbus            OH        43215  706-517-2177
# 9973         Baltimore            MD        21202  915-252-0901
# 9974          Hartford            CT         6103  360-287-3133
# 9975         Frederick            MD        21701  510-580-9594
# 9976            Newark            TX        76071  319-217-3539
# 9977          Monrovia            CA        91016  870-398-8369
# 9978      Philadelphia            DE        19103  732-930-0633
# 9979         Estelline            TX        79233  804-329-0479
# 9980        Southfield            MI        48075  304-705-9507
# 9981          Hamilton            OH        45011  206-469-0267
# 9982     Iron Mountain            MI        49801  775-308-2986
# 9983          Manassas            VA        22110  830-845-1057
# 9984          Marlboro            MA         1752  530-667-2532
# 9985            Dothan            AL        36303  562-670-9669
# 9986         Arlington            VA        20301  203-427-5963
# 9987            Salina            KS        67401  510-469-9437
# 9988           Detroit            MI        48226  208-862-6879
# 9989         Lancaster            NY        14086  608-382-6193
# 9990      Jacksonville            FL        32204  229-522-9084
# 9991       Los Angeles            CA        90071  804-421-7212
# 9992            Canton            OH        44702  724-626-2395
# 9993        Las Cruces            NM        88005  773-252-2040
# 9994           Phoenix            AZ        85034  650-477-6402
# 9995          Somerset            KY        42503  806-799-3417
# 9996             Akron            OH        44307  956-466-4313
# 9997           Gardner            KS        66030  559-585-5151
# 9998           Memphis            TN        38110  517-953-7319
# 9999           Jackson            MS        39213  630-724-3821
#
#       Phone to Name Phone Is Valid Phone Line Type Phone Is Prepaid  \
# 0          No match           True        Landline            False
# 1          No match           True        Landline            False
# 2             Match           True      Fixed VOIP            False
# 3          No match           True      Fixed VOIP            False
# 4          No match           True      Fixed VOIP            False
# 5          No match           True        Landline            False
# 6          No match           True        Landline            False
# 7          No match           True        Landline            False
# 8          No match           True  Non-fixed VOIP            False
# 9          No match           True        Landline            False
# 10         No match           True        Landline            False
# 11         No match           True        Landline            False
# 12         No match           True      Fixed VOIP            False
# 13         No match           True      Fixed VOIP            False
# 14         No match           True  Non-fixed VOIP            False
# 15         No match           True        Landline            False
# 16            Match           True        Landline            False
# 17         No match           True        Landline            False
# 18         No match           True  Non-fixed VOIP              NaN
# 19         No match           True      Fixed VOIP            False
# 20         No match           True        Landline            False
# 21            Match           True  Non-fixed VOIP            False
# 22         No match           True  Non-fixed VOIP            False
# 23         No match           True  Non-fixed VOIP            False
# 24         No match           True  Non-fixed VOIP            False
# 25         No match           True      Fixed VOIP            False
# 26            Match           True  Non-fixed VOIP            False
# 27         No match           True  Non-fixed VOIP            False
# 28            Match           True      Fixed VOIP            False
# 29         No match           True        Landline            False
# ...             ...            ...             ...              ...
# 9970       No match           True      Fixed VOIP            False
# 9971          Match           True      Fixed VOIP            False
# 9972       No match           True      Fixed VOIP            False
# 9973       No match           True  Non-fixed VOIP              NaN
# 9974       No match           True        Landline            False
# 9975       No match           True        Landline            False
# 9976       No match           True      Fixed VOIP            False
# 9977       No match           True      Fixed VOIP            False
# 9978          Match           True      Fixed VOIP            False
# 9979          Match           True      Fixed VOIP            False
# 9980       No match           True  Non-fixed VOIP              NaN
# 9981          Match           True      Fixed VOIP            False
# 9982          Match           True        Landline            False
# 9983       No match           True      Fixed VOIP            False
# 9984          Match           True      Fixed VOIP            False
# 9985  No name found           True        Landline            False
# 9986          Match           True  Non-fixed VOIP              NaN
# 9987       No match           True        Landline            False
# 9988       No match           True  Non-fixed VOIP              NaN
# 9989       No match           True        Landline            False
# 9990          Match           True      Fixed VOIP            False
# 9991       No match           True      Fixed VOIP            False
# 9992       No match           True        Landline            False
# 9993          Match           True  Non-fixed VOIP            False
# 9994          Match           True      Fixed VOIP            False
# 9995       No match           True        Landline            False
# 9996          Match           True      Fixed VOIP            False
# 9997       No match           True        Landline            False
# 9998          Match           True      Fixed VOIP            False
# 9999       No match           True      Fixed VOIP            False
#
#      Phone Is Commercial Address to Name Address Is Valid  \
# 0                   True        No match             True
# 1                  False        No match             True
# 2                   True        No match             True
# 3                   True        No match             True
# 4                   True        No match             True
# 5                   True        No match             True
# 6                   True        No match             True
# 7                   True        No match             True
# 8                   True        No match             True
# 9                   True        No match             True
# 10                  True        No match             True
# 11                  True        No match             True
# 12                  True        No match             True
# 13                  True           Match             True
# 14                  True        No match             True
# 15                 False           Match             True
# 16                  True   No name found             True
# 17                  True   No name found             True
# 18                  True        No match             True
# 19                  True        No match             True
# 20                  True        No match             True
# 21                  True           Match             True
# 22                  True        No match             True
# 23                  True           Match             True
# 24                  True        No match             True
# 25                  True        No match             True
# 26                  True        No match             True
# 27                  True        No match             True
# 28                  True           Match             True
# 29                  True        No match             True
# ...                  ...             ...              ...
# 9970                True        No match             True
# 9971                True           Match             True
# 9972                True           Match             True
# 9973                True        No match             True
# 9974                True        No match             True
# 9975                True        No match             True
# 9976                True        No match             True
# 9977                True        No match             True
# 9978                True           Match             True
# 9979                True   No name found             True
# 9980                True        No match             True
# 9981                True        No match             True
# 9982               False        No match             True
# 9983                True           Match             True
# 9984                True           Match             True
# 9985                 NaN        No match             True
# 9986                True           Match             True
# 9987                True        No match             True
# 9988                True        No match             True
# 9989                True           Match             True
# 9990                True        No match             True
# 9991                True        No match             True
# 9992                True           Match             True
# 9993                True           Match             True
# 9994                True           Match             True
# 9995                True        No match             True
# 9996                True           Match             True
# 9997                True        No match             True
# 9998                True           Match             True
# 9999                True        No match             True
#
#               Address Type Address Is Active Address Is Commercial  \
# 0               Multi unit              True                  True
# 1               Multi unit              True                  True
# 2     Unknown address type               NaN                  True
# 3              Single unit              True                 False
# 4               Multi unit              True                  True
# 5              Single unit              True                 False
# 6               Multi unit              True                  True
# 7              Single unit              True                  True
# 8              Single unit              True                 False
# 9               Multi unit              True                  True
# 10             Single unit              True                  True
# 11              Multi unit              True                  True
# 12              Multi unit              True                  True
# 13             Single unit             False                 False
# 14             Single unit              True                  True
# 15             Single unit              True                 False
# 16                  PO box              True                   NaN
# 17                  PO box              True                   NaN
# 18    Unknown address type               NaN                  True
# 19             Single unit              True                  True
# 20             Single unit              True                  True
# 21             Single unit              True                  True
# 22             Single unit              True                  True
# 23             Single unit              True                  True
# 24             Single unit              True                  True
# 25                  PO box              True                 False
# 26              Multi unit              True                  True
# 27              Multi unit              True                  True
# 28              Multi unit              True                  True
# 29    Commercial mail drop              True                  True
# ...                    ...               ...                   ...
# 9970            Multi unit              True                  True
# 9971            Multi unit              True                  True
# 9972            Multi unit              True                  True
# 9973      PO box throwback              True                  True
# 9974            Multi unit              True                  True
# 9975            Multi unit              True                  True
# 9976           Single unit              True                  True
# 9977            Multi unit              True                  True
# 9978                PO box              True                 False
# 9979  Unknown address type               NaN                   NaN
# 9980           Single unit              True                  True
# 9981           Single unit              True                  True
# 9982            Multi unit              True                  True
# 9983           Single unit              True                 False
# 9984           Single unit              True                  True
# 9985           Single unit              True                 False
# 9986            Multi unit              True                  True
# 9987           Single unit              True                  True
# 9988            Multi unit              True                  True
# 9989           Single unit              True                 False
# 9990           Single unit              True                  True
# 9991            Multi unit              True                  True
# 9992           Single unit              True                 False
# 9993            Multi unit              True                  True
# 9994            Multi unit              True                  True
# 9995           Single unit              True                  True
# 9996           Single unit              True                  True
# 9997           Single unit              True                  True
# 9998            Multi unit              True                  True
# 9999            Multi unit              True                  True
#
#       Call Disposition
# 0                    5
# 1                    5
# 2                    1
# 3                    6
# 4                    6
# 5                    6
# 6                    6
# 7                    5
# 8                    5
# 9                    5
# 10                   1
# 11                   6
# 12                   5
# 13                   1
# 14                   1
# 15                   1
# 16                   6
# 17                   6
# 18                   6
# 19                   3
# 20                   6
# 21                   6
# 22                   6
# 23                   6
# 24                   6
# 25                   1
# 26                   6
# 27                   6
# 28                   6
# 29                   6
# ...                ...
# 9970                 1
# 9971                 1
# 9972                 6
# 9973                 1
# 9974                 2
# 9975                 6
# 9976                 2
# 9977                 2
# 9978                 1
# 9979                 2
# 9980                 6
# 9981                 3
# 9982                 2
# 9983                 2
# 9984                 5
# 9985                 1
# 9986                 1
# 9987                 2
# 9988                 5
# 9989                 2
# 9990                 2
# 9991                 2
# 9992                 5
# 9993                 2
# 9994                 2
# 9995                 2
# 9996                 2
# 9997                 2
# 9998                 1
# 9999                 1
#
# [10000 rows x 19 columns]

# %%
data.iloc[0]
# Out:
# ORDER                                      1
# First Name                            Donald
# Last Name                            Mathews
# Mailing Street           789 Cambridge Place
# Mailing City                         Hanover
# Mailing State                             MD
# Mailing Zip                            21076
# Phone                           860-452-9151
# Phone to Name                       No match
# Phone Is Valid                          True
# Phone Line Type                     Landline
# Phone Is Prepaid                       False
# Phone Is Commercial                     True
# Address to Name                     No match
# Address Is Valid                        True
# Address Type                      Multi unit
# Address Is Active                       True
# Address Is Commercial                   True
# Call Disposition                           5
# Name: 0, dtype: object

# %%
data[data.'ORDER' > '500']
# Out:
#   File "<ipython-input-30-abe03d5d662d>", line 1
#     data[data.'ORDER' > '500']
#                     ^
# SyntaxError: invalid syntax

# %%
s = data.plot()

# %%
s.
